# %%
from dask.distributed import Client
client = Client(n_workers=1, threads_per_worker=4, processes=True, memory_limit='2GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:42087' processes=1 threads=4, memory=1.86 GiB>

# %%
import pandas as pd
import dask.dataframe as dd

# %%
df1=pd.read_csv('../../data/data2/raw/steps.csv')

# %%
df = dd.read_csv('../../data/data2/raw/steps.csv')
