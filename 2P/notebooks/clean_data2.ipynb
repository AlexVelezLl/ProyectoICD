# %%
import pandas as pd
import seaborn as sns
from scipy import stats
import numpy as np

# %%
path='../../data/data2/raw_2/deliveries.csv'

# %%
deliveries = pd.read_csv(path,encoding='latin-1')

# %%
date_fields = [
    "pickup_dt", "max_pickup_dt", "pickup_effective_dt",
    "delivery_dt", "max_delivery_dt", "delivery_effective_dt"
]
for field in date_fields:
    deliveries = deliveries.loc[deliveries[field] != "0000-00-00 00:00:00"]
    deliveries[field] = pd.to_datetime(deliveries[field])
deliveries.dropna(subset=date_fields, inplace=True)
deliveries.shape
# Out:
# (594268, 26)

# %%
path_steps='../../data/data2/raw_2/steps-001.csv'

# %%
steps = pd.read_csv(path_steps)

# %%
steps.drop_duplicates(inplace=True)

# %%
group_routes=steps.groupby('route_id')

# %%
group_route_delivery=deliveries.groupby('route_id')

# %%
size_complete_routes=group_routes.size()
routes_to_keep=[]
routes_not_keep=[]
for route_id, size_r in group_route_delivery.size().iteritems():
    if size_complete_routes.loc[route_id]//2 == size_r:
        routes_to_keep.append(route_id)
    else:
        routes_not_keep.append(route_id)

# %%
group_routes_to_keep=group_routes.filter(lambda x: x.name in routes_to_keep)
group_route_delivery_to_keep=group_route_delivery.filter(lambda x: x.name in routes_to_keep)

# %%
steps=group_routes_to_keep.reset_index(drop=True)
deliveries=group_route_delivery_to_keep.reset_index(drop=True)

# %%
steps= steps.merge(deliveries,left_on='delivery_id', right_on='id', how='left')

# %%
#show all columns on just one page
pd.set_option('display.max_columns', None)

# %%
columns_to_drop=['route_id_y','state','_status','items','id','max_pickup_dt','pickup_arrival_dt','pickup_dt','delivery_dt','max_delivery_dt','delivery_arrival_dt','total_package_price']

# %%
steps.drop(columns_to_drop, axis=1,inplace=True)

# %%
steps.sort_values(by=['route_id_x','step_order'],inplace=True)

# %%
steps['effective_dt']=steps.apply(lambda x: x['pickup_effective_dt'] if x['action']=='pickup' else x['delivery_effective_dt'],axis=1)

# %%
steps.drop(columns=['pickup_effective_dt','delivery_effective_dt'],inplace=True)

# %%
steps.reset_index(drop=True,inplace=True)

# %%
def get_delta_time(row, final_index):
    index = row.name
    is_last_row = index == final_index
    delta_time = 0
    if not is_last_row:
        delta_time = (steps.loc[index + 1, 'effective_dt'] -
                      steps.loc[index, 'effective_dt']).total_seconds()
    return delta_time


def get_previous_step_data(step):
    index = step.name
    is_first_step = step.step_order == 1
    time_from_previous = 0
    if not is_first_step:
        time_from_previous = (
            step.effective_dt - steps.loc[index - 1, 'effective_dt']).total_seconds()
    return time_from_previous

# %%
index_last_row=steps.shape[0]-1

# %%
index_last_row
# Out:
# 592841

# %%
steps['time_to_next']=steps.apply(lambda row: get_delta_time(row,index_last_row), axis=1)
steps['time_from_previous']=steps.apply(lambda row: get_previous_step_data(row), axis=1)

# %%
steps.columns
# Out:
# Index(['route_id_x', 'delivery_id', 'action', 'step_order', 'distance_x',
#        'total_size', 'pickupLat', 'pickupLng', 'deliveryLat', 'deliveryLng',
#        'cost', 'final_price', 'distance_y', 'shipper_id', 'distance_charged',
#        'distance_route', 'vehicle_capacity', 'effective_dt', 'time_to_next',
#        'time_from_previous'],
#       dtype='object')

# %%
steps_to_predict=steps[steps['time_to_next']<0][['route_id_x','delivery_id','distance_x']]

# %%
import pickle

# %%
loaded_model = pickle.load(open('./model.pickle', 'rb'))

# %%
result = loaded_model.predict(steps_to_predict[['distance_x']])

# %%
steps.loc[steps['time_to_next']<0,'time_to_next']=result

# %%
steps.to_csv('../../data/data2/clean_2/steps_predicted.csv', index=False)

# %%
time_to_next_percentage=steps.groupby('route_id_x').agg({'time_to_next': lambda x: (x>0).sum()/x.count() }).reset_index()

# %%
(time_to_next_percentage.time_to_next>=0).sum()
# Out:
# 9730

# %%
good_steeps=steps[(steps['time_to_next']>=0) & (steps['distance_x']!=0)][['distance_x','time_from_previous']]

# %%
good_steeps.to_csv('../../data/data2/clean_2/good_steps.csv', index=False)

# %%
steps[steps.route_id_x=='r-shiinc-1011382']
# Out:
#           route_id_x     delivery_id    action  step_order  distance_x  \
# 0   r-shiinc-1011382  t-petz-2548122    pickup           1         0.0
# 1   r-shiinc-1011382  t-petz-2547366    pickup           2         0.0
# 2   r-shiinc-1011382  t-petz-2546288    pickup           3         0.0
# 3   r-shiinc-1011382  t-petz-2546397    pickup           4         0.0
# 4   r-shiinc-1011382  t-petz-2547114    pickup           5         0.0
# 5   r-shiinc-1011382  t-petz-2547535    pickup           6         0.0
# 6   r-shiinc-1011382  t-petz-2547505    pickup           7         0.0
# 7   r-shiinc-1011382  t-petz-2546920    pickup           8         0.0
# 8   r-shiinc-1011382  t-petz-2547538    pickup           9         0.0
# 9   r-shiinc-1011382  t-petz-2546919    pickup          10         0.0
# 10  r-shiinc-1011382  t-petz-2547469    pickup          11         0.0
# 11  r-shiinc-1011382  t-petz-2546878    pickup          12         0.0
# 12  r-shiinc-1011382  t-petz-2547074    pickup          13         0.0
# 13  r-shiinc-1011382  t-petz-2547539    pickup          14         0.0
# 14  r-shiinc-1011382  t-petz-2547660    pickup          15         0.0
# 15  r-shiinc-1011382  t-petz-2547597    pickup          16         0.0
# 16  r-shiinc-1011382  t-petz-2548097    pickup          17         0.0
# 17  r-shiinc-1011382  t-petz-2547537    pickup          18         0.0
# 18  r-shiinc-1011382  t-petz-2547470    pickup          19         0.0
# 19  r-shiinc-1011382  t-petz-2547075    pickup          20         0.0
# 20  r-shiinc-1011382  t-petz-2547538  delivery          21         3.4
# 21  r-shiinc-1011382  t-petz-2547537  delivery          22         4.0
# 22  r-shiinc-1011382  t-petz-2547539  delivery          23         0.0
# 23  r-shiinc-1011382  t-petz-2547505  delivery          24         1.7
# 24  r-shiinc-1011382  t-petz-2547074  delivery          25         0.8
# 25  r-shiinc-1011382  t-petz-2546878  delivery          26         4.9
# 26  r-shiinc-1011382  t-petz-2548122  delivery          27         2.9
# 27  r-shiinc-1011382  t-petz-2547114  delivery          28         1.1
# 28  r-shiinc-1011382  t-petz-2547366  delivery          29         1.0
# 29  r-shiinc-1011382  t-petz-2546920  delivery          30         0.5
# 30  r-shiinc-1011382  t-petz-2546919  delivery          31         0.0
# 31  r-shiinc-1011382  t-petz-2546288  delivery          32         1.1
# 32  r-shiinc-1011382  t-petz-2546397  delivery          33         2.0
# 33  r-shiinc-1011382  t-petz-2547535  delivery          34         2.5
# 34  r-shiinc-1011382  t-petz-2548097  delivery          35         1.0
# 35  r-shiinc-1011382  t-petz-2547597  delivery          36         1.8
# 36  r-shiinc-1011382  t-petz-2547660  delivery          37         0.6
# 37  r-shiinc-1011382  t-petz-2547470  delivery          38         0.4
# 38  r-shiinc-1011382  t-petz-2547469  delivery          39         4.8
# 39  r-shiinc-1011382  t-petz-2547075  delivery          40        10.2
#
#     total_size  pickupLat  pickupLng  deliveryLat  deliveryLng   cost  \
# 0            1   -19.9627    -43.957     -19.9836     -43.9721   6.48
# 1            4   -19.9627    -43.957     -19.9758     -43.9748   6.48
# 2            3   -19.9627    -43.957     -19.9725     -43.9703   6.48
# 3            1   -19.9627    -43.957     -19.9650     -43.9651   6.48
# 4            3   -19.9627    -43.957     -19.9791     -43.9741   6.48
# 5            2   -19.9627    -43.957     -19.9473     -43.9719   6.48
# 6            1   -19.9627    -43.957     -19.9754     -43.9418   6.48
# 7            1   -19.9627    -43.957     -19.9743     -43.9729   6.48
# 8            3   -19.9627    -43.957     -19.9691     -43.9502   6.48
# 9            5   -19.9627    -43.957     -19.9743     -43.9729   6.48
# 10           4   -19.9627    -43.957     -19.9674     -43.9855   6.48
# 11           4   -19.9627    -43.957     -19.9758     -43.9645   6.48
# 12           1   -19.9627    -43.957     -19.9756     -43.9416   6.48
# 13           5   -19.9627    -43.957     -19.9724     -43.9412   6.48
# 14           3   -19.9627    -43.957     -19.9397     -43.9847   6.48
# 15           3   -19.9627    -43.957     -19.9397     -43.9809   6.48
# 16           2   -19.9627    -43.957     -19.9499     -43.9784   6.48
# 17           5   -19.9627    -43.957     -19.9729     -43.9415   6.48
# 18           2   -19.9627    -43.957     -19.9390     -43.9815   6.48
# 19           4   -19.9627    -43.957     -20.0150     -44.0369  11.85
# 20           3   -19.9627    -43.957     -19.9691     -43.9502   6.48
# 21           5   -19.9627    -43.957     -19.9729     -43.9415   6.48
# 22           5   -19.9627    -43.957     -19.9724     -43.9412   6.48
# 23           1   -19.9627    -43.957     -19.9754     -43.9418   6.48
# 24           1   -19.9627    -43.957     -19.9756     -43.9416   6.48
# 25           4   -19.9627    -43.957     -19.9758     -43.9645   6.48
# 26           1   -19.9627    -43.957     -19.9836     -43.9721   6.48
# 27           3   -19.9627    -43.957     -19.9791     -43.9741   6.48
# 28           4   -19.9627    -43.957     -19.9758     -43.9748   6.48
# 29           1   -19.9627    -43.957     -19.9743     -43.9729   6.48
# 30           5   -19.9627    -43.957     -19.9743     -43.9729   6.48
# 31           3   -19.9627    -43.957     -19.9725     -43.9703   6.48
# 32           1   -19.9627    -43.957     -19.9650     -43.9651   6.48
# 33           2   -19.9627    -43.957     -19.9473     -43.9719   6.48
# 34           2   -19.9627    -43.957     -19.9499     -43.9784   6.48
# 35           3   -19.9627    -43.957     -19.9397     -43.9809   6.48
# 36           3   -19.9627    -43.957     -19.9397     -43.9847   6.48
# 37           2   -19.9627    -43.957     -19.9390     -43.9815   6.48
# 38           4   -19.9627    -43.957     -19.9674     -43.9855   6.48
# 39           4   -19.9627    -43.957     -20.0150     -44.0369  11.85
#
#     final_price  distance_y  shipper_id  distance_charged  distance_route  \
# 0          10.0         5.2    170162.0               2.9             2.9
# 1          10.0         3.8    170162.0               1.0             1.0
# 2          10.0         3.2    170162.0               1.1             1.1
# 3          10.0         2.3    170162.0               2.0             2.0
# 4          10.0         4.2    170162.0               1.1             1.1
# 5          10.0         4.6    170162.0               2.5             2.5
# 6          10.0         3.1    170162.0               1.7             1.7
# 7          10.0         3.7    170162.0               0.5             0.5
# 8          10.0         3.4    170162.0               3.4             3.4
# 9          10.0         3.7    170162.0               0.0             0.0
# 10         10.0         4.8    170162.0               4.8             4.8
# 11         10.0         3.2    170162.0               4.9             4.9
# 12         10.0         3.1    170162.0               0.8             0.8
# 13         10.0         2.9    170162.0               0.0             0.0
# 14         10.0         6.7    170162.0               0.6             0.6
# 15         10.0         6.3    170162.0               1.8             1.8
# 16         10.0         5.1    170162.0               1.0             1.0
# 17         10.0         2.8    170162.0               4.0             4.0
# 18         10.0         6.4    170162.0               0.4             0.4
# 19         17.8        15.3    170162.0              10.2            10.2
# 20         10.0         3.4    170162.0               3.4             3.4
# 21         10.0         2.8    170162.0               4.0             4.0
# 22         10.0         2.9    170162.0               0.0             0.0
# 23         10.0         3.1    170162.0               1.7             1.7
# 24         10.0         3.1    170162.0               0.8             0.8
# 25         10.0         3.2    170162.0               4.9             4.9
# 26         10.0         5.2    170162.0               2.9             2.9
# 27         10.0         4.2    170162.0               1.1             1.1
# 28         10.0         3.8    170162.0               1.0             1.0
# 29         10.0         3.7    170162.0               0.5             0.5
# 30         10.0         3.7    170162.0               0.0             0.0
# 31         10.0         3.2    170162.0               1.1             1.1
# 32         10.0         2.3    170162.0               2.0             2.0
# 33         10.0         4.6    170162.0               2.5             2.5
# 34         10.0         5.1    170162.0               1.0             1.0
# 35         10.0         6.3    170162.0               1.8             1.8
# 36         10.0         6.7    170162.0               0.6             0.6
# 37         10.0         6.4    170162.0               0.4             0.4
# 38         10.0         4.8    170162.0               4.8             4.8
# 39         17.8        15.3    170162.0              10.2            10.2
#
#     vehicle_capacity        effective_dt  time_to_next  time_from_previous
# 0                  1 2022-01-03 12:30:51           0.0                 0.0
# 1                  4 2022-01-03 12:30:51           0.0                 0.0
# 2                  3 2022-01-03 12:30:51           0.0                 0.0
# 3                  1 2022-01-03 12:30:51           0.0                 0.0
# 4                  3 2022-01-03 12:30:51           0.0                 0.0
# 5                  2 2022-01-03 12:30:51           0.0                 0.0
# 6                  1 2022-01-03 12:30:51           0.0                 0.0
# 7                  1 2022-01-03 12:30:51           0.0                 0.0
# 8                  3 2022-01-03 12:30:51           0.0                 0.0
# 9                  5 2022-01-03 12:30:51           0.0                 0.0
# 10                 4 2022-01-03 12:30:51           0.0                 0.0
# 11                 4 2022-01-03 12:30:51           0.0                 0.0
# 12                 1 2022-01-03 12:30:51           0.0                 0.0
# 13                 5 2022-01-03 12:30:51           0.0                 0.0
# 14                 3 2022-01-03 12:30:51           0.0                 0.0
# 15                 3 2022-01-03 12:30:51           0.0                 0.0
# 16                 2 2022-01-03 12:30:51           0.0                 0.0
# 17                 5 2022-01-03 12:30:51           0.0                 0.0
# 18                 2 2022-01-03 12:30:51           0.0                 0.0
# 19                 4 2022-01-03 12:30:51        1996.0                 0.0
# 20                 3 2022-01-03 13:04:07        1129.0              1996.0
# 21                 5 2022-01-03 13:22:56         193.0              1129.0
# 22                 5 2022-01-03 13:26:09         581.0               193.0
# 23                 1 2022-01-03 13:35:50         519.0               581.0
# 24                 1 2022-01-03 13:44:29        1126.0               519.0
# 25                 4 2022-01-03 14:03:15         784.0              1126.0
# 26                 1 2022-01-03 14:16:19         336.0               784.0
# 27                 3 2022-01-03 14:21:55         498.0               336.0
# 28                 4 2022-01-03 14:30:13         381.0               498.0
# 29                 1 2022-01-03 14:36:34          49.0               381.0
# 30                 5 2022-01-03 14:37:23         600.0                49.0
# 31                 3 2022-01-03 14:47:23         934.0               600.0
# 32                 1 2022-01-03 15:02:57         946.0               934.0
# 33                 2 2022-01-03 15:18:43         556.0               946.0
# 34                 2 2022-01-03 15:27:59        1209.0               556.0
# 35                 3 2022-01-03 15:48:08         464.0              1209.0
# 36                 3 2022-01-03 15:55:52        -689.0               464.0
# 37                 2 2022-01-03 15:44:23        1588.0              -689.0
# 38                 4 2022-01-03 16:10:51        1581.0              1588.0
# 39                 4 2022-01-03 16:37:12      -11345.0              1581.0
