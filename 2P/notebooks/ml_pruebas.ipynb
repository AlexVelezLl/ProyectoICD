# %%
import pandas as pd

# %%
df_deliveries=pd.read_csv('../../data/data2/deliveries.csv')

# %%
df_deliveries["items"].to_list()[0]
# Out:
# '[{"id":"SFYBR004808361","qty":1,"name":"CAIXA","price":49.89,"weight":0.75,"size":2,"fragile":false,"pickedUp":true,"delivered":true,"sid":"t-amabrt-1743677_1"}]'

# %%
# Out:
#                  id          route_id  state    _status  \
# 0  t-amabrt-1743677  r-shiinc-1248030      7  completed
# 1  t-amabrt-1743713  r-shiinc-1248030      7  completed
# 2  t-amabrt-1743749  r-shiinc-1248000      7  completed
# 3  t-amabrt-1743780  r-shiinc-1248349      7  completed
# 4  t-amabrt-1743784  r-shiinc-1248030      7  completed
#
#                                                items  total_size  pickupLat  \
# 0  [{"id":"SFYBR004808361","qty":1,"name":"CAIXA"...           2   -19.9618
# 1  [{"id":"SFYBR004823678","qty":1,"name":"CAIXA"...           2   -19.9618
# 2  [{"id":"SFYBR004818385","qty":1,"name":"CAIXA"...           2   -19.9618
# 3  [{"id":"SFYBR004822031","qty":1,"name":"CAIXA"...           2   -19.9618
# 4  [{"id":"SFYBR004825735","qty":1,"name":"CAIXA"...           2   -19.9618
#
#    pickupLng  deliveryLat  deliveryLng  ...  cost final_price distance  \
# 0   -44.0285     -19.9327     -43.9440  ...  2.99        4.95     11.1
# ...

# %%
steps.
